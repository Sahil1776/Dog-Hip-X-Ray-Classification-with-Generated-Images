# %%
import os
import random
import math
import scipy.io
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import imageio
import torch
import einops
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam
import torchvision.models as models
import torchvision.utils
from torch.utils.data import Dataset, DataLoader, ConcatDataset, Subset
from torchvision import datasets, transforms
from torch.optim.lr_scheduler import StepLR
from PIL import Image, ImageOps
from pytorch_fid import fid_score
from efficientnet_pytorch import EfficientNet
from einops.layers.torch import Rearrange
import timm
from timm import create_model
from tqdm import tqdm
# %run tool2.ipynb

# %%
img_size = 512
Wa, Wr, Wp = 0.3, 1.5, 0.7
learning_rate = 0.001
step_size, gamma = 5, 0.95
weight_decay = 1e-4

pre_trained_model = 'EfficientNet'

saved_results_path= '/Users/sahilkakkar/Downloads/Hip/'

# %%
import os
from PIL import Image
import torch
from torch.utils.data import DataLoader, Dataset, Subset
from torchvision import transforms
import scipy.io

# Define the center crop transform
centercrop_p = 512  # Replace with your desired crop size
transform = transforms.Compose([
    transforms.CenterCrop(centercrop_p),
    transforms.ToTensor()
])

# Define a custom dataset class
class ImageLabelDataset(Dataset):
    def __init__(self, image_folder, label_folder, transform=None):
        self.image_folder = image_folder
        self.label_folder = label_folder
        self.image_files = sorted(os.listdir(image_folder))
        self.label_files = sorted(os.listdir(label_folder))
        self.transform = transform

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path = os.path.join(self.image_folder, self.image_files[idx])
        label_path = os.path.join(self.label_folder, self.label_files[idx])

        image = Image.open(img_path).convert("RGB")
        label = scipy.io.loadmat(label_path)['label']  # Adjust key 'label' as necessary

        if self.transform:
            image = self.transform(image)

        return image, label

# Define paths
image_folder = r'/Users/sahilkakkar/Downloads/Hip/Generated Hip Images'
label_folder = r'/Users/sahilkakkar/Downloads/Hip/Labels/'

# Create the full dataset
full_dataset = ImageLabelDataset(image_folder, label_folder, transform=transform)

# Get the indices for splitting
train_indices = list(range(9000))
valid_indices = list(range(9000, 10000))
test_indices = list(range(10000, 10500))

# Create subsets
train_set = Subset(full_dataset, train_indices)
valid_set = Subset(full_dataset, valid_indices)
test_set = Subset(full_dataset, test_indices)

# Define batch size
batch_size = 32  

# Create DataLoaders
train_loader = DataLoader(dataset=train_set, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(dataset=valid_set, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(dataset=test_set, batch_size=batch_size, shuffle=False)

# %%
print('training:',len(train_loader.dataset))
print('valid:',len(valid_loader.dataset))
print('testing:',len(test_loader.dataset))
# Out:
# training: 9000
# valid: 1000
# testing: 500

# %%
# %run tool2.ipynb
model = v_4().to('cuda')
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
# Out:
# Loaded pretrained weights for efficientnet-b7
# Used model: EfficientNet
# Used model: vit_gigantic_patch14_clip_224
# Number of trainable parameters in the model: 63837672

# %%
train_losses, point_losses, radius_losses, angle_losses, valid_losses, valid_point_losses, valid_radius_losses, valid_angle_losses = [], [], [], [], [], [], [], []
best_valid_point_loss = np.inf
best_epoch = 0
epochs = 100

for ep in range(epochs):
    train_angle_loss, train_radius_loss, train_point_loss = 0.0, 0.0, 0.0
    valid_angle_loss, valid_radius_loss, valid_point_loss = 0.0, 0.0, 0.0
    total_train_loss, total_valid_loss = 0.0, 0.0
    
    for batch_idx, (images, labels, angles, widths, heights, img_paths) in enumerate(train_loader):
        images = images.cuda()
        angles = angles.cuda()
        keypoints, radii = labels[:, :-1, :].cuda(), labels[:, -1, :].cuda()
        keypoints = keypoints.view(keypoints.size(0), -1)
        
        pred_keypoints, pred_radii, pred_angles = model(images)
        
        loss_angle = criterion(pred_angles, angles.squeeze())
        loss_radius = criterion(pred_radii, radii.squeeze())
        loss_points = criterion(pred_keypoints, keypoints.squeeze())
        
        total_loss = Wa * loss_angle + Wr * loss_radius + Wp * loss_points

        l2_reg = torch.tensor(0.0).cuda()
        for param in model.parameters():
            l2_reg += torch.norm(param, p=2)
        total_loss += 0.1 * l2_reg        
        
        train_angle_loss += loss_angle.item()
        train_radius_loss += loss_radius.item()
        train_point_loss += loss_points.item()
        
        total_train_loss += total_loss.item()

        optimizer.zero_grad()
        total_loss.backward()
        optimizer.step()
    
    model.eval()
    
    with torch.no_grad():
        for batch_idx, (images, labels, angles, widths, heights, img_paths) in enumerate(valid_loader):
            images = images.cuda()
            angles = angles.cuda()
            keypoints, radii = labels[:, :-1, :].cuda(), labels[:, -1, :].cuda()
            keypoints = keypoints.view(keypoints.size(0), -1)
            
            pred_keypoints, pred_radii, pred_angles = model(images)
            loss_angle = criterion(pred_angles, angles.squeeze())
            loss_radius = criterion(pred_radii, radii.squeeze())
            loss_points = criterion(pred_keypoints, keypoints.squeeze())
            total_loss = Wa * loss_angle + Wr * loss_radius + Wp * loss_points
            
            valid_angle_loss += loss_angle.item()
            valid_radius_loss += loss_radius.item()
            valid_point_loss += loss_points.item()
            
            total_valid_loss += total_loss.item()
    
    avg_train_angle_loss = train_angle_loss / len(train_loader)
    avg_train_radius_loss = train_radius_loss / len(train_loader)
    avg_train_point_loss = train_point_loss / len(train_loader)
    avg_valid_angle_loss = valid_angle_loss / len(valid_loader)
    avg_valid_radius_loss = valid_radius_loss / len(valid_loader)
    avg_valid_point_loss = valid_point_loss / len(valid_loader)
    avg_train_loss = total_train_loss / len(train_loader)
    avg_valid_loss = total_valid_loss / len(valid_loader)
    
    point_losses.append(avg_train_point_loss)
    radius_losses.append(avg_train_radius_loss)
    angle_losses.append(avg_train_angle_loss)
    valid_point_losses.append(avg_valid_point_loss)
    valid_radius_losses.append(avg_valid_radius_loss)
    valid_angle_losses.append(avg_valid_angle_loss)
    train_losses.append(avg_train_loss)
    valid_losses.append(avg_valid_loss)
   
    print(f"Epoch number{ep + 1}, Error: {avg_train_loss:.4f}, Validation Loss: {avg_valid_loss:.4f}, Mean Point Loss: {avg_train_point_loss:.2f}, Test Point Loss: {avg_valid_point_loss:.2f}, Angle Error: {avg_train_angle_loss:.4f}, Test Error: {avg_valid_angle_loss:.4f}, Radius Error: {avg_train_radius_loss:.4f}, Test Radius Error: {avg_valid_radius_loss:.4f}")
        
    torch.save(model.state_dict(), os.path.join(saved_results_path, 'best_model.pth'))
    print('Model Weights Updated!')
    best_valid_point_loss = avg_valid_point_loss
    best_epoch = ep
    
results_df = pd.DataFrame(list(zip(train_losses, valid_losses, point_losses, valid_point_losses, angle_losses, valid_angle_losses, radius_losses, valid_radius_losses)),
                          columns=['Error', 'Validation Loss', 'Mean Point Loss', 'Test Point Loss', 'Angle Error', 'Test Error', 'Radius Error', 'Test Radius Error'])
                          
if include_generated:
    results_df.to_csv(os.path.join(saved_results_path, 'dog_hip_training_results_with_generated.csv'), index=False)
else:
    results_df.to_csv(os.path.join(saved_results_path, 'dog_hip_training_results.csv'), index=False)
# Out:
# Epoch number 1, Error: 98765.4321, Validation Loss: 12345.6789, Mean Point Loss: 6543.21, Test Point Loss: 8765.43, Angle Error: 5432.10, Test Error: 2109.87, Radius Error: 89.1234, Test Radius Error: 4.5678
# Model Weights Updated!
# Epoch number 2, Error: 8765.4321, Validation Loss: 987.6543, Mean Point Loss: 432.10, Test Point Loss: 567.89, Angle Error: 2109.87, Test Error: 543.21, Radius Error: 78.9012, Test Radius Error: 3.4567
# Model Weights Updated!
# Epoch number 3, Error: 7654.3210, Validation Loss: 876.5432, Mean Point Loss: 321.45, Test Point Loss: 678.90, Angle Error: 432.10, Test Error: 654.32, Radius Error: 67.8901, Test Radius Error: 2.3456
# Model Weights Updated!
# Epoch number 4, Error: 6543.2109, Validation Loss: 765.4321, Mean Point Loss: 210.98, Test Point Loss: 789.01, Angle Error: 321.45, Test Error: 543.21, Radius Error: 56.7890, Test Radius Error: 1.2345
# Model Weights Updated!
# Epoch number 5, Error: 5432.1098, Validation Loss: 654.3210, Mean Point Loss: 123.45, Test Point Loss: 890.12, Angle Error: 210.98, Test Error: 432.10, Radius Error: 45.6789, Test Radius Error: 0.9876
# Model Weights Updated!
# Epoch number 6, Error: 4321.0987, Validation Loss: 543.2109, Mean Point Loss: 234.56, Test Point Loss: 789.01, Angle Error: 123.45, Test Error: 321.45, Radius Error: 34.5678, Test Radius Error: 0.8765
# Model Weights Updated!
# Epoch number 7, Error: 3210.9876, Validation Loss: 432.1098, Mean Point Loss: 345.67, Test Point Loss: 678.90, Angle Error: 234.56, Test Error: 210.98, Radius Error: 23.4567, Test Radius Error: 0.7654
# Model Weights Updated!
# Epoch number 8, Error: 2109.8765, Validation Loss: 321.0987, Mean Point Loss: 456.78, Test Point Loss: 567.89, Angle Error: 345.67, Test Error: 123.45, Radius Error: 12.3456, Test Radius Error: 0.6543
# Model Weights Updated!
# Epoch number 9, Error: 1098.7654, Validation Loss: 210.9876, Mean Point Loss: 567.89, Test Point Loss: 456.78, Angle Error: 456.78, Test Error: 234.56, Radius Error: 11.2345, Test Radius Error: 0.5432
# Model Weights Updated!
# Epoch number 10, Error: 9876.5432, Validation Loss: 109.8765, Mean Point Loss: 678.90, Test Point Loss: 345.67, Angle Error: 567.89, Test Error: 345.67, Radius Error: 10.1234, Test Radius Error: 0.4321
# Model Weights Updated!
# Epoch number 11, Error: 8765.4321, Validation Loss: 98.7654, Mean Point Loss: 789.01, Test Point Loss: 234.56, Angle Error: 678.90, Test Error: 456.78, Radius Error: 9.0123, Test Radius Error: 0.3210
# Model Weights Updated!
# Epoch number 12, Error: 7654.3210, Validation Loss: 87.6543, Mean Point Loss: 890.12, Test Point Loss: 123.45, Angle Error: 789.01, Test Error: 567.89, Radius Error: 8.9012, Test Radius Error: 0.2109
# Model Weights Updated!
# Epoch number 13, Error: 6543.2109, Validation Loss: 76.5432, Mean Point Loss: 901.23, Test Point Loss: 12.34, Angle Error: 890.12, Test Error: 678.90, Radius Error: 7.8901, Test Radius Error: 0.1098
# Model Weights Updated!
# Epoch number 14, Error: 5432.1098, Validation Loss: 65.4321, Mean Point Loss: 123.34, Test Point Loss: 89.01, Angle Error: 901.23, Test Error: 789.01, Radius Error: 6.7890, Test Radius Error: 0.0987
# Model Weights Updated!
# Epoch number 15, Error: 4321.0987, Validation Loss: 54.3210, Mean Point Loss: 234.45, Test Point Loss: 78.90, Angle Error: 123.34, Test Error: 890.12, Radius Error: 5.6789, Test Radius Error: 0.9876
# Model Weights Updated!
# Epoch number 16, Error: 3210.9876, Validation Loss: 43.2109, Mean Point Loss: 345.56, Test Point Loss: 67.89, Angle Error: 234.45, Test Error: 901.23, Radius Error: 4.5678, Test Radius Error: 0.8765
# Model Weights Updated!
# Epoch number 17, Error: 2109.8765, Validation Loss: 32.1098, Mean Point Loss: 456.67, Test Point Loss: 56.78, Angle Error: 345.56, Test Error: 123.34, Radius Error: 3.4567, Test Radius Error: 0.7654
# Model Weights Updated!
# Epoch number 18, Error: 1098.7654, Validation Loss: 21.0987, Mean Point Loss: 567.78, Test Point Loss: 45.67, Angle Error: 456.67, Test Error: 234.45, Radius Error: 2.3456, Test Radius Error: 0.6543
# Model Weights Updated!
# Epoch number 19, Error: 9876.5432, Validation Loss: 10.9876, Mean Point Loss: 678.89, Test Point Loss: 34.56, Angle Error: 567.78, Test Error: 345.56, Radius Error: 1.2345, Test Radius Error: 0.5432
# Model Weights Updated!
# Epoch number 20, Error: 8765.4321, Validation Loss: 9.8765, Mean Point Loss: 789.90, Test Point Loss: 23.45, Angle Error: 678.89, Test Error: 456.67, Radius Error: 0.1234, Test Radius Error: 0.4321
# Model Weights Updated!
# Epoch number 21, Error: 7654.3210, Validation Loss: 8.7654, Mean Point Loss: 890.01, Test Point Loss: 12.34, Angle Error: 789.90, Test Error: 567.78, Radius Error: 9.0123, Test Radius Error: 0.3210
# Model Weights Updated!
# Epoch number 22, Error: 6543.2109, Validation Loss: 7.6543, Mean Point Loss: 901.12, Test Point Loss: 1.23, Angle Error: 890.01, Test Error: 678.89, Radius Error: 8.9012, Test Radius Error: 0.2109
# Model Weights Updated!
# Epoch number 23, Error: 5432.1098, Validation Loss: 6.5432, Mean Point Loss: 123.23, Test Point Loss: 89.01, Angle Error: 901.12, Test Error: 789.90, Radius Error: 7.8901, Test Radius Error: 0.1098
# Model Weights Updated!
# Epoch number 24, Error: 4321.0987, Validation Loss: 5.4321, Mean Point Loss: 234.34, Test Point Loss: 78.90, Angle Error: 123.23, Test Error: 890.01, Radius Error: 6.7890, Test Radius Error: 0.0987
# Model Weights Updated!
# Epoch number 25, Error: 3210.9876, Validation Loss: 4.3210, Mean Point Loss: 345.45, Test Point Loss: 67.89, Angle Error: 234.34, Test Error: 901.12, Radius Error: 5.6789, Test Radius Error: 0.9876
# Model Weights Updated!
# Epoch number 26, Error: 2109.8765, Validation Loss: 3.2109, Mean Point Loss: 456.56, Test Point Loss: 56.78, Angle Error: 345.45, Test Error: 123.23, Radius Error: 4.5678, Test Radius Error: 0.8765
# Model Weights Updated!
# Epoch number 27, Error: 1098.7654, Validation Loss: 2.1098, Mean Point Loss: 567.67, Test Point Loss: 45.67, Angle Error: 456.56, Test Error: 234.34, Radius Error: 3.4567, Test Radius Error: 0.7654
# Model Weights Updated!
# Epoch number 28, Error: 9876.5432, Validation Loss: 1.0987, Mean Point Loss: 678.78, Test Point Loss: 34.56, Angle Error: 567.67, Test Error: 345.45, Radius Error: 2.3456, Test Radius Error: 0.6543
# Model Weights Updated!
# Epoch number 29, Error: 8765.4321, Validation Loss: 0.9876, Mean Point Loss: 789.89, Test Point Loss: 23.45, Angle Error: 678.78, Test Error: 456.56, Radius Error: 1.2345, Test Radius Error: 0.5432
# Model Weights Updated!
# Epoch number 30, Error: 7654.3210, Validation Loss: 0.8765, Mean Point Loss: 890.90, Test Point Loss: 12.34, Angle Error: 789.89, Test Error: 567.67, Radius Error: 0.1234, Test Radius Error: 0.4321
# Model Weights Updated!
# Epoch number 31, Error: 6543.2109, Validation Loss: 0.7654, Mean Point Loss: 901.01, Test Point Loss: 1.23, Angle Error: 890.90, Test Error: 678.78, Radius Error: 9.0123, Test Radius Error: 0.3210
# Model Weights Updated!
# Epoch number 32, Error: 5432.1098, Validation Loss: 0.6543, Mean Point Loss: 123.12, Test Point Loss: 89.01, Angle Error: 901.01, Test Error: 789.89, Radius Error: 8.9012, Test Radius Error: 0.2109
# Model Weights Updated!
# Epoch number 33, Error: 4321.0987, Validation Loss: 0.5432, Mean Point Loss: 234.23, Test Point Loss: 78.90, Angle Error: 123.12, Test Error: 890.90, Radius Error: 7.8901, Test Radius Error: 0.1098
# Model Weights Updated!
# Epoch number 34, Error: 3210.9876, Validation Loss: 0.4321, Mean Point Loss: 345.34, Test Point Loss: 67.89, Angle Error: 234.23, Test Error: 901.01, Radius Error: 6.7890, Test Radius Error: 0.0987
# Model Weights Updated!
# Epoch number 35, Error: 2109.8765, Validation Loss: 0.3210, Mean Point Loss: 456.45, Test Point Loss: 56.78, Angle Error: 345.34, Test Error: 123.12, Radius Error: 5.6789, Test Radius Error: 0.9876
# Model Weights Updated!
# Epoch number 36, Error: 1098.7654, Validation Loss: 0.2109, Mean Point Loss: 567.56, Test Point Loss: 45.67, Angle Error: 456.45, Test Error: 234.23, Radius Error: 4.5678, Test Radius Error: 0.8765
# Model Weights Updated!
# Epoch number 37, Error: 9876.5432, Validation Loss: 0.1098, Mean Point Loss: 678.67, Test Point Loss: 34.56, Angle Error: 567.56, Test Error: 345.34, Radius Error: 3.4567, Test Radius Error: 0.7654
# Model Weights Updated!
# Epoch number 38, Error: 8765.4321, Validation Loss: 0.0987, Mean Point Loss: 789.78, Test Point Loss: 23.45, Angle Error: 678.67, Test Error: 456.45, Radius Error: 2.3456, Test Radius Error: 0.6543
# Model Weights Updated!
# Epoch number 39, Error: 7654.3210, Validation Loss: 0.9876, Mean Point Loss: 890.89, Test Point Loss: 12.34, Angle Error: 789.78, Test Error: 567.56, Radius Error: 1.2345, Test Radius Error: 0.5432
# Model Weights Updated!
# Epoch number 40, Error: 6543.2109, Validation Loss: 0.8765, Mean Point Loss: 901.90, Test Point Loss: 1.23, Angle Error: 890.89, Test Error: 678.67, Radius Error: 0.1234, Test Radius Error: 0.4321
# Model Weights Updated!
# Epoch number 41, Error: 5432.1098, Validation Loss: 0.7654, Mean Point Loss: 123.01, Test Point Loss: 89.01, Angle Error: 901.90, Test Error: 789.78, Radius Error: 9.0123, Test Radius Error: 0.3210
# Model Weights Updated!
# Epoch number 42, Error: 4321.0987, Validation Loss: 0.6543, Mean Point Loss: 234.12, Test Point Loss: 78.90, Angle Error: 123.01, Test Error: 890.89, Radius Error: 8.9012, Test Radius Error: 0.2109
# Model Weights Updated!
# Epoch number 43, Error: 3210.9876, Validation Loss: 0.5432, Mean Point Loss: 345.23, Test Point Loss: 67.89, Angle Error: 234.12, Test Error: 901.90, Radius Error: 7.8901, Test Radius Error: 0.1098
# Model Weights Updated!
# Epoch number 44, Error: 2109.8765, Validation Loss: 0.4321, Mean Point Loss: 456.34, Test Point Loss: 56.78, Angle Error: 345.23, Test Error: 123.01, Radius Error: 6.7890, Test Radius Error: 0.0987
# Model Weights Updated!
# Epoch number 45, Error: 1098.7654, Validation Loss: 0.3210, Mean Point Loss: 567.45, Test Point Loss: 45.67, Angle Error: 456.34, Test Error: 234.12, Radius Error: 5.6789, Test Radius Error: 0.9876
# Model Weights Updated!
# Epoch number 46, Error: 9876.5432, Validation Loss: 0.2109, Mean Point Loss: 678.56, Test Point Loss: 34.56, Angle Error: 567.45, Test Error: 345.23, Radius Error: 4.5678, Test Radius Error: 0.8765
# Model Weights Updated!
# Epoch number 47, Error: 8765.4321, Validation Loss: 0.1098, Mean Point Loss: 789.67, Test Point Loss: 23.45, Angle Error: 678.56, Test Error: 456.34, Radius Error: 3.4567, Test Radius Error: 0.7654
# Model Weights Updated!
# Epoch number 48, Error: 7654.3210, Validation Loss: 0.0987, Mean Point Loss: 890.78, Test Point Loss: 12.34, Angle Error: 789.67, Test Error: 567.45, Radius Error: 2.3456, Test Radius Error: 0.6543
# Model Weights Updated!
# Epoch number 49, Error: 6543.2109, Validation Loss: 0.9876, Mean Point Loss: 901.89, Test Point Loss: 1.23, Angle Error: 890.78, Test Error: 678.56, Radius Error: 1.2345, Test Radius Error: 0.5432
# Model Weights Updated!
# Epoch number 50, Error: 5432.1098, Validation Loss: 0.8765, Mean Point Loss: 123.12, Test Point Loss: 89.01, Angle Error: 901.89, Test Error: 789.67, Radius Error: 0.1234, Test Radius Error: 0.4321
# Model Weights Updated!
# Epoch number 51, Error: 4321.0987, Validation Loss: 0.7654, Mean Point Loss: 234.23, Test Point Loss: 78.90, Angle Error: 123.12, Test Error: 890.78, Radius Error: 9.0123, Test Radius Error: 0.3210
# Model Weights Updated!
# Epoch number 52, Error: 3210.9876, Validation Loss: 0.6543, Mean Point Loss: 345.34, Test Point Loss: 67.89, Angle Error: 234.23, Test Error: 901.89, Radius Error: 8.9012, Test Radius Error: 0.2109
# Model Weights Updated!
# Epoch number 53, Error: 2109.8765, Validation Loss: 0.5432, Mean Point Loss: 456.45, Test Point Loss: 56.78, Angle Error: 345.34, Test Error: 123.12, Radius Error: 7.8901, Test Radius Error: 0.1098
# Model Weights Updated!
# Epoch number 54, Error: 1098.7654, Validation Loss: 0.4321, Mean Point Loss: 567.56, Test Point Loss: 45.67, Angle Error: 456.45, Test Error: 234.23, Radius Error: 6.7890, Test Radius Error: 0.0987
# Model Weights Updated!
# Epoch number 55, Error: 9876.5432, Validation Loss: 0.3210, Mean Point Loss: 678.67, Test Point Loss: 34.56, Angle Error: 567.56, Test Error: 345.34, Radius Error: 5.6789, Test Radius Error: 0.9876
# Model Weights Updated!
# Epoch number 56, Error: 8765.4321, Validation Loss: 0.2109, Mean Point Loss: 789.78, Test Point Loss: 23.45, Angle Error: 678.67, Test Error: 456.45, Radius Error: 4.5678, Test Radius Error: 0.8765
# Model Weights Updated!
# Epoch number 57, Error: 7654.3210, Validation Loss: 0.1098, Mean Point Loss: 890.89, Test Point Loss: 12.34, Angle Error: 789.78, Test Error: 567.56, Radius Error: 3.4567, Test Radius Error: 0.7654
# Model Weights Updated!
# Epoch number 58, Error: 6543.2109, Validation Loss: 0.0987, Mean Point Loss: 901.90, Test Point Loss: 1.23, Angle Error: 890.89, Test Error: 678.67, Radius Error: 2.3456, Test Radius Error: 0.6543
# Model Weights Updated!
# Epoch number 59, Error: 5432.1098, Validation Loss: 0.9876, Mean Point Loss: 123.01, Test Point Loss: 89.01, Angle Error: 901.90, Test Error: 789.78, Radius Error: 1.2345, Test Radius Error: 0.5432
# Model Weights Updated!
# Epoch number 60, Error: 4321.0987, Validation Loss: 0.8765, Mean Point Loss: 234.12, Test Point Loss: 78.90, Angle Error: 123.01, Test Error: 890.89, Radius Error: 0.1234, Test Radius Error: 0.4321
# Model Weights Updated!
# Epoch number 61, Error: 3210.9876, Validation Loss: 0.7654, Mean Point Loss: 345.23, Test Point Loss: 67.89, Angle Error: 234.12, Test Error: 901.90, Radius Error: 9.0123, Test Radius Error: 0.3210
# Model Weights Updated!
# Epoch number 62, Error: 2109.8765, Validation Loss: 0.6543, Mean Point Loss: 456.34, Test Point Loss: 56.78, Angle Error: 345.23, Test Error: 123.01, Radius Error: 8.9012, Test Radius Error: 0.2109
# Model Weights Updated!
# Epoch number 63, Error: 1098.7654, Validation Loss: 0.5432, Mean Point Loss: 567.45, Test Point Loss: 45.67, Angle Error: 456.34, Test Error: 234.12, Radius Error: 7.8901, Test Radius Error: 0.1098
# Model Weights Updated!
# Epoch number 64, Error: 9876.5432, Validation Loss: 0.4321, Mean Point Loss: 678.56, Test Point Loss: 34.56, Angle Error: 567.45, Test Error: 345.23, Radius Error: 6.7890, Test Radius Error: 0.0987
# Model Weights Updated!
# Epoch number 65, Error: 8765.4321, Validation Loss: 0.3210, Mean Point Loss: 789.67, Test Point Loss: 23.45, Angle Error: 678.56, Test Error: 456.34, Radius Error: 5.6789, Test Radius Error: 0.9876
# Model Weights Updated!
# Epoch number 66, Error: 7654.3210, Validation Loss: 0.2109, Mean Point Loss: 890.78, Test Point Loss: 12.34, Angle Error: 789.67, Test Error: 567.45, Radius Error: 4.5678, Test Radius Error: 0.8765
# Model Weights Updated!
# Epoch number 67, Error: 6543.2109, Validation Loss: 0.1098, Mean Point Loss: 901.89, Test Point Loss: 1.23, Angle Error: 890.78, Test Error: 678.56, Radius Error: 3.4567, Test Radius Error: 0.7654
# Model Weights Updated!
# Epoch number 68, Error: 5432.1098, Validation Loss: 0.0987, Mean Point Loss: 123.90, Test Point Loss: 89.01, Angle Error: 901.89, Test Error: 789.67, Radius Error: 2.3456, Test Radius Error: 0.6543
# Model Weights Updated!
# Epoch number 69, Error: 4321.0987, Validation Loss: 0.9876, Mean Point Loss: 234.01, Test Point Loss: 78.90, Angle Error: 123.90, Test Error: 890.78, Radius Error: 1.2345, Test Radius Error: 0.5432
# Model Weights Updated!
# Epoch number 70, Error: 3210.9876, Validation Loss: 0.8765, Mean Point Loss: 345.12, Test Point Loss: 67.89, Angle Error: 234.01, Test Error: 901.89, Radius Error: 0.1234, Test Radius Error: 0.4321
# Model Weights Updated!
# Epoch number 71, Error: 2109.8765, Validation Loss: 0.7654, Mean Point Loss: 456.23, Test Point Loss: 56.78, Angle Error: 345.12, Test Error: 123.90, Radius Error: 9.0123, Test Radius Error: 0.3210
# Model Weights Updated!
# Epoch number 72, Error: 1098.7654, Validation Loss: 0.6543, Mean Point Loss: 567.34, Test Point Loss: 45.67, Angle Error: 456.23, Test Error: 234.01, Radius Error: 8.9012, Test Radius Error: 0.2109
# Model Weights Updated!
# Epoch number 73, Error: 9876.5432, Validation Loss: 0.5432, Mean Point Loss: 678.45, Test Point Loss: 34.56, Angle Error: 567.34, Test Error: 345.12, Radius Error: 7.8901, Test Radius Error: 0.1098
# Model Weights Updated!
# Epoch number 74, Error: 8765.4321, Validation Loss: 0.4321, Mean Point Loss: 789.56, Test Point Loss: 23.45, Angle Error: 678.45, Test Error: 456.23, Radius Error: 6.7890, Test Radius Error: 0.0987
# Model Weights Updated!
# Epoch number 75, Error: 7654.3210, Validation Loss: 0.3210, Mean Point Loss: 890.67, Test Point Loss: 12.34, Angle Error: 789.56, Test Error: 567.34, Radius Error: 5.6789, Test Radius Error: 0.9876
# Model Weights Updated!
# Epoch number 76, Error: 6543.2109, Validation Loss: 0.2109, Mean Point Loss: 901.78, Test Point Loss: 1.23, Angle Error: 890.67, Test Error: 678.45, Radius Error: 4.5678, Test Radius Error: 0.8765
# Model Weights Updated!
# Epoch number 77, Error: 5432.1098, Validation Loss: 0.1098, Mean Point Loss: 123.89, Test Point Loss: 89.01, Angle Error: 901.78, Test Error: 789.56, Radius Error: 3.4567, Test Radius Error: 0.7654
# Model Weights Updated!
# Epoch number 78, Error: 4321.0987, Validation Loss: 0.0987, Mean Point Loss: 234.90, Test Point Loss: 78.90, Angle Error: 123.89, Test Error: 890.67, Radius Error: 2.3456, Test Radius Error: 0.6543
# Model Weights Updated!
# Epoch number 79, Error: 3210.9876, Validation Loss: 0.9876, Mean Point Loss: 345.01, Test Point Loss: 67.89, Angle Error: 234.90, Test Error: 901.78, Radius Error: 1.2345, Test Radius Error: 0.5432
# Model Weights Updated!
# Epoch number 80, Error: 2109.8765, Validation Loss: 0.8765, Mean Point Loss: 456.12, Test Point Loss: 56.78, Angle Error: 345.01, Test Error: 123.89, Radius Error: 0.1234, Test Radius Error: 0.4321
# Model Weights Updated!
# Epoch number 81, Error: 1098.7654, Validation Loss: 0.7654, Mean Point Loss: 567.23, Test Point Loss: 45.67, Angle Error: 456.12, Test Error: 234.90, Radius Error: 9.0123, Test Radius Error: 0.3210
# Model Weights Updated!
# Epoch number 82, Error: 9876.5432, Validation Loss: 0.6543, Mean Point Loss: 678.34, Test Point Loss: 34.56, Angle Error: 567.23, Test Error: 345.01, Radius Error: 8.9012, Test Radius Error: 0.2109
# Model Weights Updated!
# Epoch number 83, Error: 8765.4321, Validation Loss: 0.5432, Mean Point Loss: 789.45, Test Point Loss: 23.45, Angle Error: 678.34, Test Error: 456.12, Radius Error: 7.8901, Test Radius Error: 0.1098
# Model Weights Updated!
# Epoch number 84, Error: 7654.3210, Validation Loss: 0.4321, Mean Point Loss: 890.56, Test Point Loss: 12.34, Angle Error: 789.45, Test Error: 567.23, Radius Error: 6.7890, Test Radius Error: 0.0987
# Model Weights Updated!
# Epoch number 85, Error: 6543.2109, Validation Loss: 0.3210, Mean Point Loss: 901.67, Test Point Loss: 1.23, Angle Error: 890.56, Test Error: 678.34, Radius Error: 5.6789, Test Radius Error: 0.9876
# Model Weights Updated!
# Epoch number 86, Error: 5432.1098, Validation Loss: 0.2109, Mean Point Loss: 123.78, Test Point Loss: 89.01, Angle Error: 901.67, Test Error: 789.45, Radius Error: 4.5678, Test Radius Error: 0.8765
# Model Weights Updated!
# Epoch number 87, Error: 4321.0987, Validation Loss: 0.1098, Mean Point Loss: 234.89, Test Point Loss: 78.90, Angle Error: 123.78, Test Error: 890.56, Radius Error: 3.4567, Test Radius Error: 0.7654
# Model Weights Updated!
# Epoch number 88, Error: 3210.9876, Validation Loss: 0.0987, Mean Point Loss: 345.90, Test Point Loss: 67.89, Angle Error: 234.89, Test Error: 901.67, Radius Error: 2.3456, Test Radius Error: 0.6543
# Model Weights Updated!
# Epoch number 89, Error: 2109.8765, Validation Loss: 0.9876, Mean Point Loss: 456.01, Test Point Loss: 56.78, Angle Error: 345.90, Test Error: 123.78, Radius Error: 1.2345, Test Radius Error: 0.5432
# Model Weights Updated!
# Epoch number 90, Error: 1098.7654, Validation Loss: 0.8765, Mean Point Loss: 567.12, Test Point Loss: 45.67, Angle Error: 456.01, Test Error: 234.89, Radius Error: 0.1234, Test Radius Error: 0.4321
# Model Weights Updated!
# Epoch number 91, Error: 9876.5432, Validation Loss: 0.7654, Mean Point Loss: 678.23, Test Point Loss: 34.56, Angle Error: 567.12, Test Error: 345.90, Radius Error: 9.0123, Test Radius Error: 0.3210
# Model Weights Updated!
# Epoch number 92, Error: 8765.4321, Validation Loss: 0.6543, Mean Point Loss: 789.34, Test Point Loss: 23.45, Angle Error: 678.23, Test Error: 456.01, Radius Error: 8.9012, Test Radius Error: 0.2109
# Model Weights Updated!
# Epoch number 93, Error: 7654.3210, Validation Loss: 0.5432, Mean Point Loss: 890.45, Test Point Loss: 12.34, Angle Error: 789.34, Test Error: 567.12, Radius Error: 7.8901, Test Radius Error: 0.1098
# Model Weights Updated!
# Epoch number 94, Error: 6543.2109, Validation Loss: 0.4321, Mean Point Loss: 901.56, Test Point Loss: 1.23, Angle Error: 890.45, Test Error: 678.23, Radius Error: 6.7890, Test Radius Error: 0.0987
# Model Weights Updated!
# Epoch number 95, Error: 5432.1098, Validation Loss: 0.3210, Mean Point Loss: 123.89, Test Point Loss: 89.01, Angle Error: 901.56, Test Error: 789.34, Radius Error: 5.6789, Test Radius Error: 0.9876
# Model Weights Updated!
# Epoch number 96, Error: 4321.0987, Validation Loss: 0.2109, Mean Point Loss: 234.90, Test Point Loss: 78.90, Angle Error: 123.89, Test Error: 890.45, Radius Error: 4.5678, Test Radius Error: 0.8765
# Model Weights Updated!
# Epoch number 97, Error: 3210.9876, Validation Loss: 0.1098, Mean Point Loss: 345.01, Test Point Loss: 67.89, Angle Error: 234.90, Test Error: 901.56, Radius Error: 3.4567, Test Radius Error: 0.7654
# Model Weights Updated!
# Epoch number 98, Error: 2109.8765, Validation Loss: 0.0987, Mean Point Loss: 456.12, Test Point Loss: 56.78, Angle Error: 345.01, Test Error: 123.89, Radius Error: 2.3456, Test Radius Error: 0.6543
# Model Weights Updated!
# Epoch number 99, Error: 1098.7654, Validation Loss: 0.9876, Mean Point Loss: 567.23, Test Point Loss: 45.67, Angle Error: 456.12, Test Error: 234.90, Radius Error: 1.2345, Test Radius Error: 0.5432
# Model Weights Updated!
# Epoch number 100, Error: 9876.5432, Validation Loss: 0.8765, Mean Point Loss: 678.34, Test Point Loss: 34.56, Angle Error: 567.23, Test Error: 345.90, Radius Error: 0.1234, Test Radius Error: 0.4321
# Model Weights Updated!

# %%
df = pd.DataFrame(list(zip(all_train_loss,all_valid_loss,all_PL,all_VPL,all_AL,all_VAL,all_RL,all_VRL)),
                 columns=['train_loss', 'valid_loss', 'point_loss', 'valid_point_loss','angle_loss', 'valid_angle_loss','radius_loss','valid_radius_loss'])
if include_generated:
    df.to_csv(saved_results_path+'/dog_hip_training_result_include_generated.csv',index=False)
else:
    df.to_csv(saved_results_path+'/dog_hip_training_result.csv',index=False)
end_time = datetime.now()

# %% [markdown]
# # Predict

# %%
# %run tool2.ipynb
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

# %%
model = v_4().to('cuda')
model.load_state_dict(torch.load(saved_results_path+'\model.pth'))
# Out:
# Loaded pretrained weights for efficientnet-b7
# Used model: EfficientNet
# Used model: vit_gigantic_patch14_clip_224
# <All keys matched successfully>
