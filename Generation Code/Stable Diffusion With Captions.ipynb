# %% [markdown]
# ## Creating Dataset in Huggingface for training

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 12.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.1/316.1 kB 16.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 20.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 9.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.6.1
# ...

# %%
# !pip install --upgrade huggingface_hub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.2/417.2 kB 11.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface-hub 0.23.5
#     Uninstalling huggingface-hub-0.23.5:
#       Successfully uninstalled huggingface-hub-0.23.5
# ...

# %%
# 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

# %%
from huggingface_hub import login
login()

# %% [markdown]
# ## Text2Image

# %% [markdown]
# https://huggingface.co/docs/diffusers/training/text2image
#
# https://github.com/huggingface/diffusers/blob/main/examples/text_to_image/train_text_to_image.py

# %%
# !cd /content/

# %%
# !git clone https://github.com/huggingface/diffusers
# !pip install  ./diffusers
# !pip install .
# !pip install -U -r /content/diffusers/examples/text_to_image/requirements.txt
# Out:
# Cloning into 'diffusers'...
# remote: Enumerating objects: 66398, done.
# remote: Counting objects: 100% (647/647), done.
# remote: Compressing objects: 100% (289/289), done.
# remote: Total 66398 (delta 420), reused 465 (delta 298), pack-reused 65751
# Receiving objects: 100% (66398/66398), 47.30 MiB | 25.40 MiB/s, done.
# Resolving deltas: 100% (48909/48909), done.
# Processing ./diffusers
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for diffusers: filename=diffusers-0.30.0.dev0-py3-none-any.whl size=2467699 sha256=ec3f9ca19c66810cec45570ad23ea57548ece87070e267c746247d08ce509891
#   Stored in directory: /tmp/pip-ephem-wheel-cache-v4qn95cn/wheels/95/c5/3b/e1b4269f8a2584de57e75f949a185b48fc4144e9a91fc9965a
# Successfully built diffusers
# ...
# ERROR: Directory '.' is not installable. Neither 'setup.py' nor 'pyproject.toml' found.
# ...

# %%
# !nvidia-smi
# Out:
# Sun Jul 28 19:09:20 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !accelerate config default --mixed_precision fp16
# Out:
# accelerate configuration saved at /root/.cache/huggingface/accelerate/default_config.yaml

# %%
import os

os.environ['MODEL_NAME']=f"runwayml/stable-diffusion-v1-5"
os.environ['dataset_name']=f"/content/drive/MyDrive/Images/"
os.environ['output_dir']=f"/content/drive/MyDrive/dog_hip_output"

# %%
# !accelerate launch diffusers/examples/text_to_image/train_text_to_image.py \
  --pretrained_model_name_or_path=$MODEL_NAME \
  --dataset_name=$dataset_name \
  --use_ema \
  --resolution=512 --random_flip \
  --train_batch_size=1 \
  --gradient_accumulation_steps=4 \
  --gradient_checkpointing \
  --mixed_precision="fp16" \
  --max_train_steps=1000 \
  --learning_rate=1e-05 \
  --max_grad_norm=1 \
  --lr_scheduler="constant" --lr_warmup_steps=0 \
  --output_dir="$output_dir" \
  #--push_to_hub
# Out:
# 2024-07-28 18:26:23.059933: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-28 18:26:23.110943: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-28 18:26:23.110990: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-28 18:26:23.112444: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
from diffusers import StableDiffusionPipeline
import torch
from PIL import Image
import matplotlib.pyplot as plt

model_path = "/content/drive/MyDrive/dog_hip_output"
pipe = StableDiffusionPipeline.from_pretrained(model_path, torch_dtype=torch.float16, use_safetensors=True)
pipe.safety_checker = None
pipe.requires_safety_checker = False
pipe.to("cuda")

# Generate image
image = pipe(prompt="Centralized Specific view of a canine's hip x-ray, presenting well-defined hip joints and accompanied by a date with left angle 117.1 degrees and right angle 86.43 degrees").images[0]

# Display the image
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
prompts = ["Centralized Canine hind limb radiograph showing the hip joint anatomy, with a date marker with left angle 112.03 degrees and right angle 91.09 degrees",
    "Centralized X-ray image of the canine's hip joint, with a clear date display with left angle 63.79 degrees and right angle 61.31 degrees",
    "centralized radiographic image of canine hips with symmetrical articulations with date-time label top right corner with left angle 56.21 degrees and right angle 57.51 degrees",
    "centralized frontal pelvis radiograph showing symmetric hip joints with no fractures, dislocations with left angle 49.28 degrees and right angle 13.76 degrees",
    "centralized showing the pelvic X-ray of hip joints and upper femurs without any visible abnormalities with left angle 70.76 degrees and right angle 99.27 degrees",
    "Zoomout Radiograph of the central canine hip, including the date label with left angle 105.27 degrees and right angle 111.85 degrees",
    "zoomout symmetrical full-lengthx-ray of the pelvis and femurs with no visible fractures or dislocations with date time upper right corner with left angle 72.06 degrees and right angle 80.54 degrees",
    "zoomout canine hip x-ray image with R mark on right side of the canine, date in the Lower right corner with left angle 111.98 degrees and right angle 115.06 degrees",
    "zoomout pelvic radiograph showing symmetrical hip bones and femurs with no overt fractures or dislocations present with L mark on right side with left angle 88.52 degrees and right angle 100.57 degrees",
    "Centralized Canine hind limb radiograph showing the hip joint anatomy, with a date marker with left angle 0 degrees and right angle 120 degrees",
    "Centralized X-ray image of the canine's hip joint, with a clear date display with left angle 1 degrees and right angle 119 degrees",
    "centralized radiographic image of canine hips with symmetrical articulations with date-time label top right corner with left angle 2 degrees and right angle 118 degrees",
    "centralized frontal pelvis radiograph showing symmetric hip joints with no fractures, dislocations with left angle 3 degrees and right angle 10 degrees",
    "centralized showing the pelvic X-ray of hip joints and upper femurs without any visible abnormalities with left angle 4 degrees and right angle 12 degrees",
    "Zoomout Radiograph of the central canine hip, including the date label with left angle 5 degrees and right angle 15 degrees",
    "zoomout symmetrical full-lengthx-ray of the pelvis and femurs with no visible fractures or dislocations with date time upper right corner with left angle 6 degrees and right angle 80 degrees",
    "zoomout canine hip x-ray image with R mark on right side of the canine, date in the Lower right corner with left angle 8 degrees and right angle 60 degrees",
    "zoomout pelvic radiograph showing symmetrical hip bones and femurs with no overt fractures or dislocations present with L mark on right side with left angle 10 degrees and right angle 90 degrees",
    "Centralized Canine hind limb radiograph showing the hip joint anatomy, with a date marker with left angle 70 degrees and right angle 10 degrees",
    "Centralized X-ray image of the canine's hip joint, with a clear date display with left angle 100 degrees and right angle 80 degrees",
    "centralized radiographic image of canine hips with symmetrical articulations with date-time label top right corner with left angle 86 degrees and right angle 120 degrees",
    "centralized frontal pelvis radiograph showing symmetric hip joints with no fractures, dislocations with left angle 110 degrees and right angle 106 degrees",
    "centralized showing the pelvic X-ray of hip joints and upper femurs without any visible abnormalities with left angle 53 degrees and right angle 73 degrees",
    "Zoomout Radiograph of the central canine hip, including the date label with left angle 41 degrees and right angle 60 degrees",
    "zoomout symmetrical full-lengthx-ray of the pelvis and femurs with no visible fractures or dislocations with date time upper right corner with left angle 78 degrees and right angle 8 degrees",
    "zoomout canine hip x-ray image with R mark on right side of the canine, date in the Lower right corner with left angle 8 degrees and right angle 60 degrees",
    "zoomout pelvic radiograph showing symmetrical hip bones and femurs with no overt fractures or dislocations present with L mark on right side with left angle 91 degrees and right angle 9 degrees",
    "Centralized Canine hind limb radiograph showing the hip joint anatomy, with a date marker with left angle 0 degrees and right angle 120 degrees",
    "Centralized X-ray image of the canine's hip joint, with a clear date display with left angle 86 degrees and right angle 78 degrees",
    "centralized radiographic image of canine hips with symmetrical articulations with date-time label top right corner with left angle 20 degrees and right angle 11 degrees",
    "centralized frontal pelvis radiograph showing symmetric hip joints with no fractures, dislocations with left angle 36 degrees and right angle 1 degrees",
    "centralized showing the pelvic X-ray of hip joints and upper femurs without any visible abnormalities with left angle 48 degrees and right angle 72 degrees",
    "Zoomout Radiograph of the central canine hip, including the date label with left angle 59 degrees and right angle 105 degrees",
    "zoomout symmetrical full-lengthx-ray of the pelvis and femurs with no visible fractures or dislocations with date time upper right corner with left angle 66 degrees and right angle 76 degrees",
    "zoomout canine hip x-ray image with R mark on right side of the canine, date in the Lower right corner with left angle 8 degrees and right angle 60 degrees",
    "zoomout pelvic radiograph showing symmetrical hip bones and femurs with no overt fractures or dislocations present with L mark on right side with left angle 110 degrees and right angle 98 degrees",
    "Centralized Canine hind limb radiograph showing the hip joint anatomy, with a date marker with left angle 108 degrees and right angle 10 degrees",
    "Centralized X-ray image of the canine's hip joint, with a clear date display with left angle 112 degrees and right angle 101 degrees",
    "centralized radiographic image of canine hips with symmetrical articulations with date-time label top right corner with left angle 26 degrees and right angle 106 degrees",
    "centralized frontal pelvis radiograph showing symmetric hip joints with no fractures, dislocations with left angle 96 degrees and right angle 88 degrees",
    "centralized showing the pelvic X-ray of hip joints and upper femurs without any visible abnormalities with left angle 49 degrees and right angle 98 degrees",
    "Zoomout Radiograph of the central canine hip, including the date label with left angle 105 degrees and right angle 105 degrees",
    "zoomout symmetrical full-lengthx-ray of the pelvis and femurs with no visible fractures or dislocations with date time upper right corner with left angle 61 degrees and right angle 81 degrees",
    "zoomout canine hip x-ray image with R mark on right side of the canine, date in the Lower right corner with left angle 78 degrees and right angle 70 degrees",
    "zoomout pelvic radiograph showing symmetrical hip bones and femurs with no overt fractures or dislocations present with L mark on right side with left angle 16 degrees and right angle 69 degrees",
    "Centralized Canine hind limb radiograph showing the hip joint anatomy, with a date marker with left angle 100 degrees and right angle 15 degrees",
    "Centralized X-ray image of the canine's hip joint, with a clear date display with left angle 111 degrees and right angle 96 degrees",
    "centralized radiographic image of canine hips with symmetrical articulations with date-time label top right corner with left angle 21 degrees and right angle 18 degrees",
    "centralized frontal pelvis radiograph showing symmetric hip joints with no fractures, dislocations with left angle 113 degrees and right angle 67 degrees",
    "centralized showing the pelvic X-ray of hip joints and upper femurs without any visible abnormalities with left angle 64 degrees and right angle 72 degrees",
    "Zoomout Radiograph of the central canine hip, including the date label with left angle 55 degrees and right angle 85 degrees",
    "zoomout symmetrical full-lengthx-ray of the pelvis and femurs with no visible fractures or dislocations with date time upper right corner with left angle 86 degrees and right angle 87 degrees",
    "zoomout canine hip x-ray image with R mark on right side of the canine, date in the Lower right corner with left angle 48 degrees and right angle 40 degrees",
    "zoomout pelvic radiograph showing symmetrical hip bones and femurs with no overt fractures or dislocations present with L mark on right side with left angle 77 degrees and right angle 107 degrees"]
len(prompts)
# Out:
# 54

# %%
k = 0
for i in range(0,371):
  for prompt in prompts:
    image = pipe(prompt).images[0]
    image.save(f"/content/drive/MyDrive/hip_generated/2_{k}.png")
    k+=1
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-9a713c53ce93> in <cell line: 2>()
#       2 for i in range(0,371):
#       3   for prompt in prompts:
# ----> 4     image = pipe(prompt).images[0]
#       5     image.save(f"/content/drive/MyDrive/hip_generated/2_{k}.png")
#       6     k+=1
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# ...

# %%
from diffusers import StableDiffusionPipeline
import torch
from PIL import Image
import matplotlib.pyplot as plt

model_path = "/content/drive/MyDrive/dog_hip_output"
pipe = StableDiffusionPipeline.from_pretrained(model_path, torch_dtype=torch.float16, use_safetensors=True)
pipe.safety_checker = None
pipe.requires_safety_checker = False
pipe.to("cuda")

# Set the number of rows and columns for the grid
num_rows, num_cols = 4, 4

# Create a subplot with the specified number of rows and columns
fig, axs = plt.subplots(num_rows, num_cols, figsize=(12, 12))

# Generate and display images in the grid
for row in range(num_rows):
    for col in range(num_cols):
        # Generate image
        image = pipe(prompt="Zoomout Canine hip joint x-ray image, centered placement, with a date displayed on the top right with left angle 103.83 degrees and right angle 117.92 degrees").images[0]

        # Display the image in the current subplot
        axs[row, col].imshow(image)
        axs[row, col].axis('off')

# Adjust layout for better spacing
plt.tight_layout()

# Show the plot with the grid of images
plt.show()

# %%
from diffusers import StableDiffusionPipeline
import torch
import os

model_path = "/content/drive/MyDrive/dog_hip_output"
pipe = StableDiffusionPipeline.from_pretrained(model_path, torch_dtype=torch.float16, use_safetensors=True)
pipe.safety_checker = None
pipe.requires_safety_checker = False
pipe.to("cuda")

# Set the number of rows and columns for the grid
num_rows, num_cols = 4, 4

# Create a directory to store the generated images
output_dir = "/content/drive/MyDrive/new_generated_img"
os.makedirs(output_dir, exist_ok=True)

# Generate and save images in the grid
for row in range(num_rows):
    for col in range(num_cols):
        # Generate image
        image = pipe(prompt="Zoomout Canine hip joint x-ray image, centered placement, with a date displayed on the top right with left angle 103.83 degrees and right angle 117.92 degrees").images[0]

        # Define the filename
        filename = f"generated_image_{row}_{col}.png"

        # Save the image
        image.save(os.path.join(output_dir, filename))

# Print confirmation message
print(f"Generated images saved to {output_dir}")
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generated images saved to /content/drive/MyDrive/new_generated_img
